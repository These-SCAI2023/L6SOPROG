# %%
#
import numpy as np
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split

# %%
#Je suis désolée, je suis malade chez moi (je vous ai laissé un message sur moodle car je n'ai pas votre mail)
#J'ai pris du temps à lire et comprendre les slides du courps après qu'elles ont été postés, puis je suis vraiment lente pour la programmation
#J'ai donc eu le temps que de faire ce début de td,je l'envérrai au complet plus tard

# %%
# !head /kaggle/input/textos/Ressources-20240329/edgar_allan_poe.txt
# !head /kaggle/input/textos/Ressources-20240329/robert_frost.txt
# Out:
# LO! Death hath rear'd himself a throne
# In a strange city, all alone,
# Far down within the dim west
# Where the good, and the bad, and the worst, and the best,
# Have gone to their eternal rest.
#
# There shrines, and palaces, and towers
# Are not like any thing of ours
# Oh no! O no! ours never loom
# To heaven with that ungodly gloom!
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there

# %%
input_files = []

def get_nom(chemin):
    fichier1 = chemin.split('/')
    fichier2 = fichier1[-1]
    return fichier2

# %%
input_files.append(get_nom('/kaggle/input/textos/Ressources-20240329/edgar_allan_poe.txt'))
input_files.append(get_nom('/kaggle/input/textos/Ressources-20240329/robert_frost.txt'))
print(input_files)
# Out:
# ['edgar_allan_poe.txt', 'robert_frost.txt']

# %%
input_text = []
labels = []

# %%
for elm in enumerate(input_files):
    f = elm[1]
    label = elm[0]
